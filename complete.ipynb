# %%
import numpy as np
import pandas as pd
import random
from random import randint
from datetime import date
import datetime

# %% [markdown]
# nd for edu_end2

# %%
np.random.seed(1234567)
rnd =np.round(np.random.normal(0, 1, 1000), 2)
nd= rnd.tolist()
nd[0:10]
# Out:
# [-0.51, -0.45, 1.73, 0.64, 0.03, 0.08, -0.8, -0.63, -0.35, 0.97]

# %% [markdown]
# nd1 for race category

# %%
np.random.seed(54321)
rnd1 =np.round(np.random.normal(0, 1, 1000), 2)
nd1= rnd1.tolist()
nd1[0:10]
# Out:
# [0.22, 0.74, -0.33, 1.39, -2.3, 1.14, 0.06, -0.08, -0.65, -0.02]

# %% [markdown]
# nd2 for bacehlors end_month, end_month2

# %%
np.random.seed(98321)
rnd2 =np.round(np.random.normal(0, 1, 1000), 2)
nd2= rnd2.tolist()
nd2[0:10]
# Out:
# [-2.0, 0.24, -0.31, -0.18, 1.47, -1.23, -0.41, 1.11, 0.63, -0.61]

# %%
 nd3 for end_month3, edu_start3

# %%
np.random.seed(7654321)
rnd3 =np.round(np.random.normal(0, 1, 1000), 2)
nd3= rnd3.tolist()
nd3[0:10]
# Out:
# [-0.7, -0.04, 0.37, 0.37, 0.02, -0.47, -1.58, 0.17, -1.07, -0.8]

# %%
np.random.seed(218914)
exrnd =np.round(np.random.normal(0, 1, 1000), 2)
exnd= exrnd.tolist()
exnd[0:10]
# Out:
# [0.63, 0.76, -0.03, -1.01, -0.44, 0.31, -0.4, -0.79, -1.16, -0.51]

# %%
random.seed(12345)
id= random.sample(range(1, 1001), 1000) 
print (id[0:100])
# Out:
# [427, 751, 11, 840, 846, 823, 306, 876, 378, 955, 199, 277, 580, 447, 166, 383, 128, 896, 444, 268, 576, 643, 179, 627, 567, 192, 364, 756, 999, 94, 544, 754, 423, 600, 517, 171, 152, 211, 737, 80, 195, 858, 350, 330, 25, 470, 348, 28, 523, 708, 763, 426, 4, 7, 680, 892, 168, 790, 595, 184, 294, 102, 669, 425, 109, 907, 698, 592, 187, 755, 385, 239, 537, 611, 727, 845, 338, 827, 42, 238, 123, 895, 512, 222, 931, 822, 775, 569, 686, 191, 264, 603, 445, 531, 133, 43, 169, 309, 886, 853]

# %%
np.random.seed(12345)
gendercategory = []
for z in nd:
    if z > 0.50:
        gendercategory.append('Female')
    else:
        gendercategory.append("Male")
gendercategory[1:10]
# Out:
# ['Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Male', 'Male', 'Female']

# %%
np.random.seed(12345)
racecategory = []
for z in nd1:
    if z <-0.75:
        racecategory.append('Asian Indian')
    elif z < 0:
        racecategory.append('Native Americans')
    elif z < 1:
        racecategory.append('African Americans')
    elif z <1.5:
        racecategory.append('White Americans')
    elif z < 1.75:
        racecategory.append("Native Hawaiian Americans")
    else:
        racecategory.append('West Indian ancestry')
racecategory[0:6]
# Out:
# ['African Americans',
#  'African Americans',
#  'Native Americans',
#  'White Americans',
#  'Asian Indian',
#  'White Americans']

# %%
np.random.seed(12345)
nationality = []
for z in nd1:
    if z <-0.75:
        nationality.append('Indian')
    elif z < 1.75:
        nationality.append('American')
    else:
        nationality.append('Chinese')
nationality[0:6]
# Out:
# ['American', 'American', 'American', 'American', 'Indian', 'American']

# %%
np.random.seed(12345)
homecity = []
for z in nd1:
    if z <-1.25:
        homecity.append('Delhi')
    elif z < -0.95:
        homecity.append('Mumbai')
    elif z < -0.75:
        homecity.append('Hyderabad')
    elif z < -0.55:
        homecity.append('Dallas')
    elif z < -0.25:
        homecity.append('Houston')
    elif z < 0:
        homecity.append('New York')
    elif z < 0.4:
        homecity.append('Chicago')
    elif z < 1:
        homecity.append('San Jose')
    elif z <1.5:
        homecity.append('San Francisco')
    elif z < 1.75:
        homecity.append("Washington")
    else:
        homecity.append('Mumbai')
homecity[0:6]
# Out:
# ['Chicago', 'San Jose', 'Houston', 'San Francisco', 'Delhi', 'San Francisco']

# %%
random.seed(12345)
dob_year = [ randint(1965,1990) for k in range(1000)]
dob_month = [ randint(1,12) for k in range(1000)]
dob_day = [ randint(1,28) for k in range(1000)]

# %%
dict_p = {"id":id, "Race":racecategory, "Homecity":homecity, "Nationality":nationality,
          "Gender":gendercategory, "dob_year":dob_year,"dob_month":dob_month,"dob_day":dob_day}
final_personal_details = pd.DataFrame(dict_p)
final_personal_details.head(15)
# Out:
#      id               Race       Homecity Nationality  Gender  dob_year  \
# 0   427  African Americans        Chicago    American    Male      1978
# 1   751  African Americans       San Jose    American    Male      1988
# 2    11   Native Americans        Houston    American  Female      1965
# 3   840    White Americans  San Francisco    American  Female      1990
# 4   846       Asian Indian          Delhi      Indian    Male      1974
# 5   823    White Americans  San Francisco    American    Male      1976
# 6   306  African Americans        Chicago    American    Male      1971
# 7   876   Native Americans       New York    American    Male      1973
# 8   378   Native Americans         Dallas    American    Male      1983
# 9   955   Native Americans       New York    American  Female      1978
# 10  199   Native Americans         Dallas    American  Female      1970
# 11  277  African Americans        Chicago    American    Male      1976
# ...

# %%
personal_details = final_personal_details.copy()
personal_details['nd'] = nd

# %%
personal_details['edu_start'] = personal_details['dob_year'] + 16
personal_details.loc[(personal_details.nd <= 0 )& (personal_details.nd >= -1), 'edu_start'] = personal_details['dob_year'] + 17
personal_details.loc[(personal_details.nd > 0 )& (personal_details.nd <= 1), 'edu_start'] = personal_details['dob_year'] + 18
personal_details.loc[(personal_details.nd > 1 )& (personal_details.nd <= 1.5), 'edu_start'] = personal_details['dob_year'] + 19
personal_details.loc[(personal_details.nd > 1.5 ), 'edu_start'] = personal_details['dob_year'] + random.randint(15,20)

# %%
personal_details.head()
# Out:
#     id               Race       Homecity Nationality  Gender  dob_year  \
# 0  427  African Americans        Chicago    American    Male      1978
# 1  751  African Americans       San Jose    American    Male      1988
# 2   11   Native Americans        Houston    American  Female      1965
# 3  840    White Americans  San Francisco    American  Female      1990
# 4  846       Asian Indian          Delhi      Indian    Male      1974
#
#    dob_month  dob_day    nd  edu_start
# 0          8       25 -0.51       1995
# 1          6       10 -0.45       2005
# 2          9        7  1.73       1983
# 3          5       11  0.64       2008
# 4         12        2  0.03       1992

# %%
edu_start = personal_details["edu_start"].tolist()

# %%
edu_start[0:10]
# Out:
# [1995, 2005, 1983, 2008, 1992, 1994, 1988, 1990, 2000, 1996]

# %%
np.random.seed(1269)
start_month = []
for z in nd1:
    if z <-1.15:
        start_month.append('9')
    elif z < -0.10:
        start_month.append('8')
    elif z < 1.0:
        start_month.append('1')
    elif z < 2:
        start_month.append('2')
    else:
        start_month.append('5')
start_month[0:10]
# Out:
# ['1', '1', '8', '2', '9', '2', '1', '1', '8', '1']

# %%
random.seed(54678)
start_day = [ randint(1,28) for k in range(1000)]

# %%
np.random.seed(1234567)
degree = []
for deg in range(1000):
    deg = np.random.randint(0,4)
    if deg == 0:
        degree.append('BSc Engineering')
    elif deg == 1:
        degree.append('Bachelor of Technology')
    elif deg == 2:
        degree.append('Bachelor of Arts')
    else:
        degree.append('Bachelor of Science')
degree[0:10]
# Out:
# ['Bachelor of Science',
#  'Bachelor of Science',
#  'BSc Engineering',
#  'Bachelor of Arts',
#  'Bachelor of Technology',
#  'Bachelor of Arts',
#  'BSc Engineering',
#  'Bachelor of Technology',
#  'BSc Engineering',
#  'Bachelor of Technology']

# %%
degree_type = ["Bachelor's Degree" for deg in range(1000)]

# %%
dict_edu = {"id":id, "nd":nd,"nd1":nd1,"degree_type":degree_type, "degree":degree,"edu_start":edu_start,
            "start_month":start_month, "start_day":start_day}

# %%
edu_details = pd.DataFrame(dict_edu)
edu_details.head()
# Out:
#     id    nd   nd1        degree_type                  degree  edu_start  \
# 0  427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1  751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2   11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3  840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4  846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
#
#   start_month  start_day
# 0           1         20
# 1           1         19
# 2           8          6
# 3           2          7
# 4           9         24

# %%
edu_details['edu_end'] = edu_details['edu_start'] + random.randint(5,7)
edu_details.loc[(edu_details.nd1 < -0.5 ), 'edu_end'] = edu_details['edu_start'] + 3
edu_details.loc[(edu_details.nd1 < 1.25 ) & (edu_details.nd1 >= -0.5), 'edu_end'] = edu_details['edu_start'] + 4
edu_details.loc[(edu_details.nd1 < 2 ) & (edu_details.nd1 >= 1.25), 'edu_end'] = edu_details['edu_start'] + 5

edu_details.head()
# Out:
#     id    nd   nd1        degree_type                  degree  edu_start  \
# 0  427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1  751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2   11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3  840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4  846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
#
#   start_month  start_day  edu_end  end_month  end_day      degree_type2  \
# 0           1         20     1999         12        8  Masters's Degree
# 1           1         19     2009          5       20  Masters's Degree
# 2           8          6     1987         12       11  Masters's Degree
# 3           2          7     2013         12       13  Masters's Degree
# 4           9         24     1995          7        8  Masters's Degree
#
#                              degree2  edu_start2  start_month2  start_day2  \
# ...

# %%
np.random.seed(546978)
end_month = []
for z in nd2:
    if z <0:
        end_month.append('12')
    elif z < 0.90:
        end_month.append('5')
    elif z < 1.3:
        end_month.append('4')
    else:
        end_month.append('7')
end_month[0:6]

random.seed(546978)
end_day = [ randint(7,20) for k in range(1000)]

# %%
edu_details['end_month'] = end_month
edu_details['end_day'] = end_day

edu_details.head()
# Out:
#     id    nd   nd1        degree_type                  degree  edu_start  \
# 0  427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1  751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2   11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3  840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4  846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
#
#   start_month  start_day  edu_end end_month  end_day      degree_type2  \
# 0           1         20     1999        12        8  Masters's Degree
# 1           1         19     2009         5       20  Masters's Degree
# 2           8          6     1987        12       11  Masters's Degree
# 3           2          7     2013        12       13  Masters's Degree
# 4           9         24     1995         7        8  Masters's Degree
#
#                              degree2  edu_start2  start_month2  start_day2  \
# ...

# %%
np.random.seed(12345678)
degree2 = []
for deg in range(1000):
    deg = np.random.randint(0,13)
    if deg == 0:
        degree2.append('Master of Philosphy')
    elif deg == 1:
        degree2.append('Master of Business Administration')
    elif deg == 2:
        degree2.append('Master of Science')
    elif deg == 3:
        degree2.append('Master of Science')  
    else:
        degree2.append('0')
degree2[0:10]
# Out:
# ['Master of Science',
#  'Master of Science',
#  '0',
#  'Master of Business Administration',
#  'Master of Philosphy',
#  '0',
#  'Master of Business Administration',
#  '0',
#  'Master of Science',
#  '0']

# %%
degree_type2 = ["Masters's Degree" for deg in range(1000)]
edu_details['degree_type2'] = degree_type2
edu_details['degree2'] = degree2
edu_details.head()
# Out:
#     id    nd   nd1        degree_type                  degree  edu_start  \
# 0  427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1  751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2   11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3  840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4  846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
#
#   start_month  start_day  edu_end end_month  end_day      degree_type2  \
# 0           1         20     1999        12        8  Masters's Degree
# 1           1         19     2009         5       20  Masters's Degree
# 2           8          6     1987        12       11  Masters's Degree
# 3           2          7     2013        12       13  Masters's Degree
# 4           9         24     1995         7        8  Masters's Degree
#
#                              degree2  edu_start2  start_month2  start_day2  \
# ...

# %%
np.random.seed(12345)
nationality = []
for z in nd1:
    if z <0:
        edu_details['edu_start2'] = edu_details['edu_end'] + 0
    elif z <0.5:
        edu_details['edu_start2'] = edu_details['edu_end'] + 1
    elif z <1.5:
        edu_details['edu_start2'] = edu_details['edu_end'] + 2
    else:
        edu_details['edu_start2'] = edu_details['edu_end'] + randint(3,5)
nationality[0:6]

edu_details.head(15)
# Out:
#      id    nd   nd1        degree_type                  degree  edu_start  \
# 0   427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1   751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2    11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3   840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4   846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
# 5   823  0.08  1.14  Bachelor's Degree        Bachelor of Arts       1994
# 6   306 -0.80  0.06  Bachelor's Degree         BSc Engineering       1988
# 7   876 -0.63 -0.08  Bachelor's Degree  Bachelor of Technology       1990
# 8   378 -0.35 -0.65  Bachelor's Degree         BSc Engineering       2000
# 9   955  0.97 -0.02  Bachelor's Degree  Bachelor of Technology       1996
# 10  199  0.71 -0.57  Bachelor's Degree        Bachelor of Arts       1988
# 11  277 -2.16  0.05  Bachelor's Degree        Bachelor of Arts       1992
# ...

# %%
np.random.seed(12698)
start_month2 = []
for z in nd1:
    if z <-1.15:
        start_month2.append('9')
    elif z < -0.10:
        start_month2.append('8')
    elif z < 1.0:
        start_month2.append('1')
    elif z < 2:
        start_month2.append('2')
    else:
        start_month2.append('5')
start_month2[0:10]
# Out:
# ['1', '1', '8', '2', '9', '2', '1', '1', '8', '1']

# %%
random.seed(546789)
start_day2 = [ randint(1,28) for k in range(1000)]

edu_details['start_month2'] = start_month2
edu_details['start_day2']= start_day2

edu_details.head(10)
# Out:
#     id    nd   nd1        degree_type                  degree  edu_start  \
# 0  427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1  751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2   11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3  840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4  846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
# 5  823  0.08  1.14  Bachelor's Degree        Bachelor of Arts       1994
# 6  306 -0.80  0.06  Bachelor's Degree         BSc Engineering       1988
# 7  876 -0.63 -0.08  Bachelor's Degree  Bachelor of Technology       1990
# 8  378 -0.35 -0.65  Bachelor's Degree         BSc Engineering       2000
# 9  955  0.97 -0.02  Bachelor's Degree  Bachelor of Technology       1996
#
#   start_month  start_day  edu_end end_month  end_day      degree_type2  \
# 0           1         20     1999        12        8  Masters's Degree
# ...

# %%
edu_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
# id              1000 non-null int64
# nd              1000 non-null float64
# nd1             1000 non-null float64
# degree_type     1000 non-null object
# degree          1000 non-null object
# edu_start       1000 non-null int64
# start_month     1000 non-null object
# start_day       1000 non-null int64
# edu_end         1000 non-null int64
# end_month       1000 non-null object
# end_day         1000 non-null int64
# degree_type2    1000 non-null object
# degree2         1000 non-null object
# edu_start2      1000 non-null int64
# start_month2    1000 non-null object
# start_day2      1000 non-null int64
# edu_end2        1000 non-null int64
# end_month2      1000 non-null object
# end_day2        1000 non-null int64
# dtypes: float64(2), int64(9), object(8)
# memory usage: 148.5+ KB

# %%
edu_details['end_month'] = edu_details['end_month'].astype(str).astype(int)
edu_details['start_month2'] = edu_details['start_month2'].astype(str).astype(int)

# %%
edu_details.loc[(edu_details['edu_end'] == edu_details['edu_start2'])&(edu_details['end_month']==12),'edu_start2'] = edu_details['edu_end'] +1
edu_details.loc[(edu_details['edu_end'] == edu_details['edu_start2'])&(edu_details['end_month']<11),'start_month2'] = randint(8,9)

edu_details.head()
# Out:
#     id    nd   nd1        degree_type                  degree  edu_start  \
# 0  427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1  751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2   11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3  840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4  846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
#
#   start_month  start_day  edu_end  end_month  end_day      degree_type2  \
# 0           1         20     1999         12        8  Masters's Degree
# 1           1         19     2009          5       20  Masters's Degree
# 2           8          6     1987         12       11  Masters's Degree
# 3           2          7     2013         12       13  Masters's Degree
# 4           9         24     1995          7        8  Masters's Degree
#
#                              degree2  edu_start2  start_month2  start_day2  \
# ...

# %%
edu_details['edu_end2'] = edu_details['edu_start2'] + [random.randint(1,3) for k in range(1000)]
edu_details.loc[(edu_details.nd < -2 ), 'edu_end2'] = edu_details['edu_start2'] + 3
edu_details.loc[(edu_details.nd < 0.5 ) & (edu_details.nd >= -2), 'edu_end2'] = edu_details['edu_start2'] + 2
edu_details.loc[(edu_details.nd < 1.25 ) & (edu_details.nd >= 0.5), 'edu_end2'] = edu_details['edu_start2'] + 1
edu_details.loc[(edu_details.nd < 1.5 ) & (edu_details.nd >= 1.25), 'edu_end2'] = edu_details['edu_start2'] + 4

edu_details.head()
# Out:
#     id    nd   nd1        degree_type                  degree  edu_start  \
# 0  427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1  751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2   11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3  840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4  846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
#
#   start_month  start_day  edu_end  end_month  end_day      degree_type2  \
# 0           1         20     1999         12        8  Masters's Degree
# 1           1         19     2009          5       20  Masters's Degree
# 2           8          6     1987         12       11  Masters's Degree
# 3           2          7     2013         12       13  Masters's Degree
# 4           9         24     1995          7        8  Masters's Degree
#
#                              degree2  edu_start2  start_month2  start_day2  \
# ...

# %%
np.random.seed(54988)
end_month2 = []
for z in nd2:
    if z <0:
        end_month2.append('12')
    elif z < 0.90:
        end_month2.append('5')
    elif z < 1.3:
        end_month2.append('4')
    else:
        end_month2.append('7')
end_month2[0:10]
# Out:
# ['12', '5', '12', '12', '7', '12', '12', '4', '5', '12']

# %%
random.seed(54678)
end_day2 = [ randint(1,28) for k in range(1000)]

# %%
edu_details['end_month2'] = end_month2
edu_details['end_day2'] = end_day2
edu_details.head()
# Out:
#     id    nd   nd1        degree_type                  degree  edu_start  \
# 0  427 -0.51  0.22  Bachelor's Degree     Bachelor of Science       1995
# 1  751 -0.45  0.74  Bachelor's Degree     Bachelor of Science       2005
# 2   11  1.73 -0.33  Bachelor's Degree         BSc Engineering       1983
# 3  840  0.64  1.39  Bachelor's Degree        Bachelor of Arts       2008
# 4  846  0.03 -2.30  Bachelor's Degree  Bachelor of Technology       1992
#
#   start_month  start_day  edu_end  end_month  end_day      degree_type2  \
# 0           1         20     1999         12        8  Masters's Degree
# 1           1         19     2009          5       20  Masters's Degree
# 2           8          6     1987         12       11  Masters's Degree
# 3           2          7     2013         12       13  Masters's Degree
# 4           9         24     1995          7        8  Masters's Degree
#
#                              degree2  edu_start2  start_month2  start_day2  \
# ...

# %%
df_degree1 = edu_details.loc[:,['id','degree_type','degree', 'edu_start','start_month','start_day', 'edu_end', 'end_month','end_day']]
df_degree1.head(15)
# Out:
#      id        degree_type                  degree  edu_start start_month  \
# 0   427  Bachelor's Degree     Bachelor of Science       1995           1
# 1   751  Bachelor's Degree     Bachelor of Science       2005           1
# 2    11  Bachelor's Degree         BSc Engineering       1983           8
# 3   840  Bachelor's Degree        Bachelor of Arts       2008           2
# 4   846  Bachelor's Degree  Bachelor of Technology       1992           9
# 5   823  Bachelor's Degree        Bachelor of Arts       1994           2
# 6   306  Bachelor's Degree         BSc Engineering       1988           1
# 7   876  Bachelor's Degree  Bachelor of Technology       1990           1
# 8   378  Bachelor's Degree         BSc Engineering       2000           8
# 9   955  Bachelor's Degree  Bachelor of Technology       1996           1
# 10  199  Bachelor's Degree        Bachelor of Arts       1988           8
# 11  277  Bachelor's Degree        Bachelor of Arts       1992           1
# ...

# %%
df_degree2 = edu_details.loc[:,['id','degree_type2','degree2', 'edu_start2','start_month2','start_day2', 'edu_end2','end_month2','end_day2']]
df_degree2 = df_degree2.drop(df_degree2[df_degree2.degree2 =='0'].index)
df_degree2.head()
# Out:
#     id      degree_type2                            degree2  edu_start2  \
# 0  427  Masters's Degree                  Master of Science        2000
# 1  751  Masters's Degree                  Master of Science        2009
# 3  840  Masters's Degree  Master of Business Administration        2014
# 4  846  Masters's Degree                Master of Philosphy        1995
# 6  306  Masters's Degree  Master of Business Administration        1993
#
#    start_month2  start_day2  edu_end2 end_month2  end_day2
# 0             1          16      2002         12        20
# 1             8           4      2011          5        19
# 3             2           6      2015         12         7
# 4             8           6      1997          7        24
# 6             1          20      1995         12        24

# %%
index = ['id','degree_type', 'degree','edu_start','start_month','start_day','edu_end','end_month','end_day']
df_degree2.columns = index

# %%
df_degree12 = pd.concat([df_degree1, df_degree2], axis=0)

# %%
df_degree12 = df_degree12.sort_values(["id", "edu_end"],axis=0, ascending=True)
df_degree12 = df_degree12.reset_index(drop=True)
df_degree12.head(10)
# Out:
#    id        degree_type                  degree  edu_start start_month  \
# 0   1  Bachelor's Degree         BSc Engineering       1993           1
# 1   1   Masters's Degree       Master of Science       1997           8
# 2   2  Bachelor's Degree  Bachelor of Technology       1991           8
# 3   3  Bachelor's Degree  Bachelor of Technology       1983           9
# 4   4  Bachelor's Degree  Bachelor of Technology       1988           9
# 5   5  Bachelor's Degree         BSc Engineering       1991           1
# 6   6  Bachelor's Degree         BSc Engineering       1984           1
# 7   7  Bachelor's Degree     Bachelor of Science       1991           1
# 8   8  Bachelor's Degree        Bachelor of Arts       1989           8
# 9   9  Bachelor's Degree        Bachelor of Arts       1986           8
#
#    start_day  edu_end end_month  end_day
# 0         24     1997         5       14
# 1         24     1999         5       24
# 2         13     1995         7       11
# ...

# %%
df_degree12d = df_degree12.drop_duplicates(subset='id', keep='last')
df_degree12d = df_degree12d.reset_index(drop=True)
df_degree12d.head(7)
# Out:
#    id        degree_type                  degree  edu_start start_month  \
# 0   1   Masters's Degree       Master of Science       1997           8
# 1   2  Bachelor's Degree  Bachelor of Technology       1991           8
# 2   3  Bachelor's Degree  Bachelor of Technology       1983           9
# 3   4  Bachelor's Degree  Bachelor of Technology       1988           9
# 4   5  Bachelor's Degree         BSc Engineering       1991           1
# 5   6  Bachelor's Degree         BSc Engineering       1984           1
# 6   7  Bachelor's Degree     Bachelor of Science       1991           1
#
#    start_day  edu_end end_month  end_day
# 0         24     1999         5       24
# 1         13     1995         7       11
# 2          2     1986         7       16
# 3         14     1991        12        8
# 4         19     1995         7        8
# 5         20     1988        12       13
# 6         12     1995         5       11

# %%
df_degree12ds= df_degree12d.loc[:,['id','degree','edu_end','end_month','end_day']]
df_degree12ds.head()
# Out:
#    id                  degree  edu_end end_month  end_day
# 0   1       Master of Science     1999         5       24
# 1   2  Bachelor of Technology     1995         7       11
# 2   3  Bachelor of Technology     1986         7       16
# 3   4  Bachelor of Technology     1991        12        8
# 4   5         BSc Engineering     1995         7        8

# %%
np.random.seed(1234567)
degree3 = []
for deg in range(1000):
    deg = np.random.randint(10,35)
    if deg == 11:
        degree3.append('Doctor of Business Administration')
    elif deg == 15:
        degree3.append('Doctor of Philosophy PhD')
    elif deg == 19:
        degree3.append('PhD')  
    else:
        degree3.append('0')
degree3[0:10]
# Out:
# ['0', '0', '0', 'Doctor of Philosophy PhD', '0', '0', '0', '0', '0', '0']

# %%
df_degree12ds['degree3'] = degree3

degree_type3 = ["PhD Degree" for deg in range(1000)]
df_degree12ds['degree_type3']  = degree_type3

# %%
df_degree12ds.head(10)
# Out:
#    id                             degree  edu_end end_month  end_day  \
# 0   1                  Master of Science     1999         5       24
# 1   2             Bachelor of Technology     1995         7       11
# 2   3             Bachelor of Technology     1986         7       16
# 3   4             Bachelor of Technology     1991        12        8
# 4   5                    BSc Engineering     1995         7        8
# 5   6                    BSc Engineering     1988        12       13
# 6   7                Bachelor of Science     1995         5       11
# 7   8                   Bachelor of Arts     1992        12       15
# 8   9  Master of Business Administration     1991        12        1
# 9  10                Bachelor of Science     2007         5       17
#
#                     degree3 degree_type3
# 0                         0   PhD Degree
# 1                         0   PhD Degree
# 2                         0   PhD Degree
# ...

# %%
df_degree12ds['edu_start3'] = df_degree12d['edu_end'] + [random.randint(0,3) for k in range(1000)]

# %%
np.random.seed(1269)
start_month3 = []
for z in nd1:
    if z <-1.15:
        start_month3.append('9')
    elif z < -0.10:
        start_month3.append('8')
    elif z < 1.0:
        start_month3.append('1')
    elif z < 2:
        start_month3.append('2')
    else:
        start_month3.append('5')
start_month3[0:10]

random.seed(546789)
start_day3 = [ randint(1,28) for k in range(1000)]

df_degree12ds['start_month3'] = start_month3
df_degree12ds['start_day3']= start_day3

df_degree12ds.head(10)
# Out:
#    id                             degree  edu_end end_month  end_day  \
# 0   1                  Master of Science     1999         5       24
# 1   2             Bachelor of Technology     1995         7       11
# 2   3             Bachelor of Technology     1986         7       16
# 3   4             Bachelor of Technology     1991        12        8
# 4   5                    BSc Engineering     1995         7        8
# 5   6                    BSc Engineering     1988        12       13
# 6   7                Bachelor of Science     1995         5       11
# 7   8                   Bachelor of Arts     1992        12       15
# 8   9  Master of Business Administration     1991        12        1
# 9  10                Bachelor of Science     2007         5       17
#
#                     degree3 degree_type3  edu_start3 start_month3  start_day3
# 0                         0   PhD Degree        2001            1          16
# ...

# %%
df_degree12ds['nd3'] = nd3

# %%
df_degree12ds['edu_end3'] = df_degree12ds['edu_start3'] + random.randint(3,7)
df_degree12ds.loc[(df_degree12ds.nd3 < -1.75 ), 'edu_end3'] = df_degree12ds['edu_start3'] + 3
df_degree12ds.loc[(df_degree12ds.nd3 < 0.25 ) & (df_degree12ds.nd3 >= -1.75), 'edu_end3'] = df_degree12ds['edu_start3'] + 4
df_degree12ds.loc[(df_degree12ds.nd3 < 1.5 ) & (df_degree12ds.nd3 >= 0.25), 'edu_end3'] = df_degree12ds['edu_start3'] + 5
df_degree12ds.loc[(df_degree12ds.nd3 < 1.75 ) & (df_degree12ds.nd3 >= 1.5), 'edu_end3'] = df_degree12ds['edu_start3'] + 6
df_degree12ds.head()
# Out:
#    id                  degree  edu_end end_month  end_day  \
# 0   1       Master of Science     1999         5       24
# 1   2  Bachelor of Technology     1995         7       11
# 2   3  Bachelor of Technology     1986         7       16
# 3   4  Bachelor of Technology     1991        12        8
# 4   5         BSc Engineering     1995         7        8
#
#                     degree3 degree_type3  edu_start3 start_month3  start_day3  \
# 0                         0   PhD Degree        2001            1          16
# 1                         0   PhD Degree        1995            1           4
# 2                         0   PhD Degree        1988            8           8
# 3  Doctor of Philosophy PhD   PhD Degree        1994            2           6
# 4                         0   PhD Degree        1995            9           6
#
#     nd3  edu_end3
# 0 -0.70      2005
# 1 -0.04      1999
# 2  0.37      1993
# 3  0.37      1999
# 4  0.02      1999

# %%
np.random.seed(549788)
end_month3 = []
for z in nd3:
    if z <0:
        end_month3.append('12')
    elif z < 0.90:
        end_month3.append('5')
    elif z < 1.3:
        end_month3.append('4')
    else:
        end_month3.append('7')

random.seed(5469788)
end_day3 = [ randint(7,20) for k in range(1000)]

df_degree12ds['end_month3'] = end_month3
df_degree12ds['end_day3']= end_day3

df_degree12ds.head(10)
# Out:
#    id                             degree  edu_end end_month  end_day  \
# 0   1                  Master of Science     1999         5       24
# 1   2             Bachelor of Technology     1995         7       11
# 2   3             Bachelor of Technology     1986         7       16
# 3   4             Bachelor of Technology     1991        12        8
# 4   5                    BSc Engineering     1995         7        8
# 5   6                    BSc Engineering     1988        12       13
# 6   7                Bachelor of Science     1995         5       11
# 7   8                   Bachelor of Arts     1992        12       15
# 8   9  Master of Business Administration     1991        12        1
# 9  10                Bachelor of Science     2007         5       17
#
#                     degree3 degree_type3  edu_start3 start_month3  start_day3  \
# 0                         0   PhD Degree        2001            1          16
# ...

# %%
df_degree12ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
# id              1000 non-null int64
# degree          1000 non-null object
# edu_end         1000 non-null int64
# end_month       1000 non-null object
# end_day         1000 non-null int64
# degree3         1000 non-null object
# degree_type3    1000 non-null object
# edu_start3      1000 non-null int64
# start_month3    1000 non-null object
# start_day3      1000 non-null int64
# nd3             1000 non-null float64
# edu_end3        1000 non-null int64
# end_month3      1000 non-null object
# end_day3        1000 non-null int64
# dtypes: float64(1), int64(7), object(6)
# memory usage: 109.5+ KB

# %%
df_degree12ds['end_month'] = df_degree12ds['end_month'].astype(str).astype(int)
df_degree12ds['start_month3'] = df_degree12ds['start_month3'].astype(str).astype(int)

# %%
df_degree12ds.loc[(df_degree12ds['edu_end'] == df_degree12ds['edu_start3']) & (df_degree12ds['end_month']==12),'edu_start3'] = df_degree12ds['edu_end'] +1
df_degree12ds.loc[(df_degree12ds['edu_end'] == df_degree12ds['edu_start3']) & (df_degree12ds['end_month'] <= 11),'start_month3'] = randint(8,9)

df_degree12ds.head(15)
# Out:
#     id                             degree  edu_end  end_month  end_day  \
# 0    1                  Master of Science     1999          5       24
# 1    2             Bachelor of Technology     1995          7       11
# 2    3             Bachelor of Technology     1986          7       16
# 3    4             Bachelor of Technology     1991         12        8
# 4    5                    BSc Engineering     1995          7        8
# 5    6                    BSc Engineering     1988         12       13
# 6    7                Bachelor of Science     1995          5       11
# 7    8                   Bachelor of Arts     1992         12       15
# 8    9  Master of Business Administration     1991         12        1
# 9   10                Bachelor of Science     2007          5       17
# 10  11                    BSc Engineering     1987         12       11
# 11  12                    BSc Engineering     1985          5       10
# ...

# %%
df_degree3 = df_degree12ds.loc[:,['id','degree_type3','degree3', 'edu_start3','start_month3','start_day3', 'edu_end3','end_month3','end_day3']]

# %%
index2= index = ['id','degree_type', 'degree','edu_start','start_month','start_day','edu_end','end_month','end_day']
df_degree3.columns = index2

# %%
df_degree3 = df_degree3.drop(df_degree3[df_degree3.degree =='0'].index)
df_degree3.head()
# Out:
#     id degree_type                             degree  edu_start  start_month  \
# 3    4  PhD Degree           Doctor of Philosophy PhD       1994            2
# 14  15  PhD Degree           Doctor of Philosophy PhD       2010            8
# 23  24  PhD Degree  Doctor of Business Administration       1988            1
# 37  38  PhD Degree                                PhD       2000            2
# 42  43  PhD Degree           Doctor of Philosophy PhD       2001            8
#
#     start_day  edu_end end_month  end_day
# 3           6     1999         5       18
# 14         24     2014         5       11
# 23          7     1993         5       19
# 37         13     2005         5       19
# 42         21     2003         7       15

# %%
final_edu = pd.concat([df_degree12, df_degree3], axis=0)
final_edu = final_edu.sort_values(["id","edu_start"],axis=0, ascending=True)
final_edu = final_edu.reset_index(drop=True)
final_edu.head(25)
# Out:
#     id        degree_type                             degree  edu_start  \
# 0    1  Bachelor's Degree                    BSc Engineering       1993
# 1    1   Masters's Degree                  Master of Science       1997
# 2    2  Bachelor's Degree             Bachelor of Technology       1991
# 3    3  Bachelor's Degree             Bachelor of Technology       1983
# 4    4  Bachelor's Degree             Bachelor of Technology       1988
# 5    4         PhD Degree           Doctor of Philosophy PhD       1994
# 6    5  Bachelor's Degree                    BSc Engineering       1991
# 7    6  Bachelor's Degree                    BSc Engineering       1984
# 8    7  Bachelor's Degree                Bachelor of Science       1991
# 9    8  Bachelor's Degree                   Bachelor of Arts       1989
# 10   9  Bachelor's Degree                   Bachelor of Arts       1986
# 11   9   Masters's Degree  Master of Business Administration       1990
# ...

# %%
final_edu = final_edu.drop(final_edu[final_edu.edu_end >= 2019].index)
final_edu
# Out:
#         id        degree_type                             degree  edu_start  \
# 0        1  Bachelor's Degree                    BSc Engineering       1993
# 1        1   Masters's Degree                  Master of Science       1997
# 2        2  Bachelor's Degree             Bachelor of Technology       1991
# 3        3  Bachelor's Degree             Bachelor of Technology       1983
# 4        4  Bachelor's Degree             Bachelor of Technology       1988
# 5        4         PhD Degree           Doctor of Philosophy PhD       1994
# 6        5  Bachelor's Degree                    BSc Engineering       1991
# 7        6  Bachelor's Degree                    BSc Engineering       1984
# 8        7  Bachelor's Degree                Bachelor of Science       1991
# 9        8  Bachelor's Degree                   Bachelor of Arts       1989
# 10       9  Bachelor's Degree                   Bachelor of Arts       1986
# ...

# %%
final_edu.to_csv('education.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-279-3e65c32614d4> in <module>
# ----> 1 final_edu.to_csv('education.csv',index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
# ...

# %%
df_eduend = final_edu.drop_duplicates(subset='id', keep='last')
df_eduend = df_eduend.reset_index(drop=True)
df_eduend
# Out:
#        id        degree_type                             degree  edu_start  \
# 0       1   Masters's Degree                  Master of Science       1997
# 1       2  Bachelor's Degree             Bachelor of Technology       1991
# 2       3  Bachelor's Degree             Bachelor of Technology       1983
# 3       4         PhD Degree           Doctor of Philosophy PhD       1994
# 4       5  Bachelor's Degree                    BSc Engineering       1991
# 5       6  Bachelor's Degree                    BSc Engineering       1984
# 6       7  Bachelor's Degree                Bachelor of Science       1991
# 7       8  Bachelor's Degree                   Bachelor of Arts       1989
# 8       9   Masters's Degree  Master of Business Administration       1990
# 9      10  Bachelor's Degree                Bachelor of Science       2004
# 10     11  Bachelor's Degree                    BSc Engineering       1983
# ...

# %%
work_details =df_eduend.loc[:,['id','edu_end']]
work_details.loc[:,'exnd'] = exnd
work_details[0:10]
# Out:
#    id  edu_end  exnd
# 0   1     1999  0.63
# 1   2     1995  0.76
# 2   3     1986 -0.03
# 3   4     1999 -1.01
# 4   5     1995 -0.44
# 5   6     1988  0.31
# 6   7     1995 -0.40
# 7   8     1992 -0.79
# 8   9     1991 -1.16
# 9  10     2007 -0.51

# %%
work_details.loc[(work_details.exnd <= 0 ), 'w_start1'] = work_details['edu_end'] + 0
work_details.loc[(work_details.exnd > 0 )& (work_details.exnd <= 1.5), 'w_start1'] = work_details['edu_end'] +1
work_details.loc[(work_details.exnd > 1.5 ), 'w_start1'] = work_details['edu_end'] + randint(2,4)

# %%
work_details.head()
# Out:
#    id  edu_end  exnd  w_start1
# 0   1     1999  0.63    2000.0
# 1   2     1995  0.76    1996.0
# 2   3     1986 -0.03    1986.0
# 3   4     1999 -1.01    1999.0
# 4   5     1995 -0.44    1995.0

# %%
work_details.loc[(work_details.w_start1 <= 1990), 'w_end1'] = work_details['w_start1'] + randint(6,12)
work_details.loc[(work_details.w_start1 <= 1995 )& (work_details.w_start1 > 1990), 'w_end1'] =  work_details['w_start1'] + randint(4,9)
work_details.loc[(work_details.w_start1 <= 2000 )& (work_details.w_start1 > 1995), 'w_end1'] = work_details['w_start1'] + randint(1,5)
work_details.loc[(work_details.w_start1 > 2000 ), 'w_end1'] = work_details['w_start1'] + 1
work_details.head()
# Out:
#    id  edu_end  exnd  w_start1  w_end1
# 0   1     1999  0.63    2000.0  2004.0
# 1   2     1995  0.76    1996.0  2000.0
# 2   3     1986 -0.03    1986.0  1994.0
# 3   4     1999 -1.01    1999.0  2003.0
# 4   5     1995 -0.44    1995.0  2003.0

# %%
work_details['nd'] =nd

# %%
work_details.loc[(work_details.nd <= 0.1 ), 'w_start2'] = work_details['w_end1'] + 0
work_details.loc[(work_details.nd > 0.1 ), 'w_start2'] = work_details['w_end1'] + 1

# %%
work_details.head()
# Out:
#    id  edu_end  exnd  w_start1  w_end1    nd  w_start2
# 0   1     1999  0.63    2000.0  2004.0 -0.51    2004.0
# 1   2     1995  0.76    1996.0  2000.0 -0.45    2000.0
# 2   3     1986 -0.03    1986.0  1994.0  1.73    1995.0
# 3   4     1999 -1.01    1999.0  2003.0  0.64    2004.0
# 4   5     1995 -0.44    1995.0  2003.0  0.03    2003.0

# %%
work_details.loc[(work_details.w_start2 <= 1990), 'w_end2'] = work_details['w_start2'] + randint(6,14)
work_details.loc[(work_details.w_start2 <= 1997 )& (work_details.w_start2 > 1990), 'w_end2'] =  work_details['w_start2'] + randint(4,9)
work_details.loc[(work_details.w_start2 <= 2005 )& (work_details.w_start2 > 1997), 'w_end2'] = work_details['w_start2'] + randint(1,5)
work_details.head()
# Out:
#    id  edu_end  exnd  w_start1  w_end1    nd  w_start2  w_end2
# 0   1     1999  0.63    2000.0  2004.0 -0.51    2004.0  2007.0
# 1   2     1995  0.76    1996.0  2000.0 -0.45    2000.0  2003.0
# 2   3     1986 -0.03    1986.0  1994.0  1.73    1995.0  1999.0
# 3   4     1999 -1.01    1999.0  2003.0  0.64    2004.0  2007.0
# 4   5     1995 -0.44    1995.0  2003.0  0.03    2003.0  2006.0

# %%
work_details.loc[(work_details.exnd >= 0.3 ), 'w_start3'] = work_details['w_end2'] + 0
work_details.loc[(work_details.exnd < 0.3 ), 'w_start3'] = work_details['w_end2'] + 1

# %%
work_details.head(15)
# Out:
#     id  edu_end  exnd  w_start1  w_end1    nd  w_start2  w_end2  w_start3
# 0    1     1999  0.63    2000.0  2004.0 -0.51    2004.0  2007.0    2007.0
# 1    2     1995  0.76    1996.0  2000.0 -0.45    2000.0  2003.0    2003.0
# 2    3     1986 -0.03    1986.0  1994.0  1.73    1995.0  1999.0    2000.0
# 3    4     1999 -1.01    1999.0  2003.0  0.64    2004.0  2007.0    2008.0
# 4    5     1995 -0.44    1995.0  2003.0  0.03    2003.0  2006.0    2007.0
# 5    6     1988  0.31    1989.0  1997.0  0.08    1997.0  2001.0    2001.0
# 6    7     1995 -0.40    1995.0  2003.0 -0.80    2003.0  2006.0    2007.0
# 7    8     1992 -0.79    1992.0  2000.0 -0.63    2000.0  2003.0    2004.0
# 8    9     1991 -1.16    1991.0  1999.0 -0.35    1999.0  2002.0    2003.0
# 9   10     2007 -0.51    2007.0  2008.0  0.97    2009.0     NaN       NaN
# 10  11     1987 -1.77    1987.0  1995.0  0.71    1996.0  2000.0    2001.0
# 11  12     1985  0.22    1986.0  1994.0 -2.16    1994.0  1998.0    1999.0
# ...

# %%
work_details.loc[(work_details.w_start3 <= 2005), 'w_end3'] = work_details['w_start3'] + randint(6,12)
work_details.loc[(work_details.w_start3 <= 2008 )& (work_details.w_start3 > 2005), 'w_end3'] =  work_details['w_start3'] + randint(4,8)
work_details.loc[(work_details.w_start3 <= 2012 )& (work_details.w_start3 > 2009), 'w_end3'] = work_details['w_start3'] + randint(2,4)
work_details.loc[(work_details.w_start3 <= 2015 )& (work_details.w_start3 > 2012), 'w_end3'] = work_details['w_start3'] + randint(1,2)

# %%
work_details
# Out:
#        id  edu_end  exnd  w_start1  w_end1    nd  w_start2  w_end2  w_start3  \
# 0       1     1999  0.63    2000.0  2004.0 -0.51    2004.0  2007.0    2007.0
# 1       2     1995  0.76    1996.0  2000.0 -0.45    2000.0  2003.0    2003.0
# 2       3     1986 -0.03    1986.0  1994.0  1.73    1995.0  1999.0    2000.0
# 3       4     1999 -1.01    1999.0  2003.0  0.64    2004.0  2007.0    2008.0
# 4       5     1995 -0.44    1995.0  2003.0  0.03    2003.0  2006.0    2007.0
# 5       6     1988  0.31    1989.0  1997.0  0.08    1997.0  2001.0    2001.0
# 6       7     1995 -0.40    1995.0  2003.0 -0.80    2003.0  2006.0    2007.0
# 7       8     1992 -0.79    1992.0  2000.0 -0.63    2000.0  2003.0    2004.0
# 8       9     1991 -1.16    1991.0  1999.0 -0.35    1999.0  2002.0    2003.0
# 9      10     2007 -0.51    2007.0  2008.0  0.97    2009.0     NaN       NaN
# 10     11     1987 -1.77    1987.0  1995.0  0.71    1996.0  2000.0    2001.0
# ...

# %%
work_details.to_csv('work1.csv',index=False)

# %%
wex1 = work_details[['id','w_start1','w_end1']]
wex1d = wex1.dropna(how='any')
wex1d
# Out:
#        id  w_start1  w_end1
# 0       1    2000.0  2004.0
# 1       2    1996.0  2000.0
# 2       3    1986.0  1994.0
# 3       4    1999.0  2003.0
# 4       5    1995.0  2003.0
# 5       6    1989.0  1997.0
# 6       7    1995.0  2003.0
# 7       8    1992.0  2000.0
# 8       9    1991.0  1999.0
# 9      10    2007.0  2008.0
# 10     11    1987.0  1995.0
# 11     12    1986.0  1994.0
# 12     13    1999.0  2003.0
# 13     14    2008.0  2009.0
# 14     15    2015.0  2016.0
# 15     16    1986.0  1994.0
# 16     17    2007.0  2008.0
# 17     18    1998.0  2002.0
# 18     19    2013.0  2014.0
# 19     20    2001.0  2002.0
# 20     21    1995.0  2003.0
# 21     22    1985.0  1993.0
# 22     23    1991.0  1999.0
# 23     24    1993.0  2001.0
# 24     25    2011.0  2012.0
# 25     26    2001.0  2002.0
# 26     27    2007.0  2008.0
# 27     28    1989.0  1997.0
# 28     29    2002.0  2003.0
# 29     30    2008.0  2009.0
# ..    ...       ...     ...
# 970   971    1993.0  2001.0
# ...

# %%
wex2 = work_details[['id','w_start2','w_end2']]
wex2 = wex2.dropna(how='any')

# %%
wex3 = work_details[['id','w_start3','w_end3']]
wex3 = wex3.dropna(how='any')

# %%
index = ['id','w_start', 'w_end']
wex1.columns = index
wex2.columns = index
wex3.columns = index
we123 = pd.concat([wex1, wex2, wex3])
we123 = we123.sort_values(["id","w_end"],axis=0, ascending=True)
we123 = we123.reset_index(drop=True)
we123.head(25)
# Out:
#     id  w_start   w_end
# 0    1   2000.0  2004.0
# 1    1   2004.0  2007.0
# 2    1   2007.0  2014.0
# 3    2   1996.0  2000.0
# 4    2   2000.0  2003.0
# 5    2   2003.0  2011.0
# 6    3   1986.0  1994.0
# 7    3   1995.0  1999.0
# 8    3   2000.0  2008.0
# 9    4   1999.0  2003.0
# 10   4   2004.0  2007.0
# 11   4   2008.0  2015.0
# 12   5   1995.0  2003.0
# 13   5   2003.0  2006.0
# 14   5   2007.0  2014.0
# 15   6   1989.0  1997.0
# 16   6   1997.0  2001.0
# 17   6   2001.0  2009.0
# 18   7   1995.0  2003.0
# 19   7   2003.0  2006.0
# 20   7   2007.0  2014.0
# 21   8   1992.0  2000.0
# 22   8   2000.0  2003.0
# 23   8   2004.0  2012.0
# 24   9   1991.0  1999.0

# %%
we123.to_csv('we123.csv',index=False)

# %% [markdown]
# current company start year = last company end year

# %%
we123d = we123.drop_duplicates(subset='id', keep='last')
we123d = we123d.reset_index(drop=True)
we123d
# Out:
#        id  w_start   w_end
# 0       1   2007.0  2014.0
# 1       2   2003.0  2011.0
# 2       3   2000.0  2008.0
# 3       4   2008.0  2015.0
# 4       5   2007.0  2014.0
# 5       6   2001.0  2009.0
# 6       7   2007.0  2014.0
# 7       8   2004.0  2012.0
# 8       9   2003.0  2011.0
# 9      10   2007.0  2008.0
# 10     11   2001.0  2009.0
# 11     12   1999.0  2007.0
# 12     13   2008.0  2015.0
# 13     14   2008.0  2009.0
# 14     15   2015.0  2016.0
# 15     16   2000.0  2008.0
# 16     17   2007.0  2008.0
# 17     18   2007.0  2014.0
# 18     19   2013.0  2014.0
# 19     20   2006.0  2013.0
# 20     21   2007.0  2014.0
# 21     22   1998.0  2006.0
# 22     23   2002.0  2010.0
# 23     24   2006.0  2013.0
# 24     25   2011.0  2012.0
# 25     26   2006.0  2013.0
# 26     27   2007.0  2008.0
# 27     28   2001.0  2009.0
# 28     29   2007.0  2014.0
# 29     30   2008.0  2009.0
# ..    ...      ...     ...
# 970   971   2005.0  2013.0
# 971   972   2017.0  2018.0
# ...

# %%
we123d['nd3'] = nd3
we123d.loc[(we123d.nd3 >= 0.3 ), 'p_start1'] = we123d['w_end'] + 0
we123d.loc[(we123d.nd3 < 0.3 ), 'p_start1'] = we123d['w_end'] + 1
p_start1 = we123d['p_start1'].tolist()
p_start1[0:8]
# Out:
# [2015.0, 2012.0, 2008.0, 2015.0, 2015.0, 2010.0, 2015.0, 2013.0]

# %%
p_exp = we123d[['id','p_start1']]
p_exp.head()
# Out:
#    id  p_start1
# 0   1    2015.0
# 1   2    2012.0
# 2   3    2008.0
# 3   4    2015.0
# 4   5    2015.0

# %%
p_exp.loc[(p_exp.p_start1 < 1999), 'p_end1'] = p_exp['p_start1'] + randint(6,10)
p_exp.loc[(p_exp.p_start1 >= 1999 )& (p_exp.p_start1 < 2005), 'p_end1'] =  p_exp['p_start1'] + randint(5,9)
p_exp.loc[(p_exp.p_start1 >= 2005 )& (p_exp.p_start1 < 2010), 'p_end1'] = p_exp['p_start1'] + randint(4,6)
p_exp.loc[(p_exp.p_start1 >= 2010 )& (p_exp.p_start1 < 2013), 'p_end1'] = p_exp['p_start1'] + randint(2,4)
p_exp.loc[(p_exp.p_start1 >= 2013 )& (p_exp.p_start1 < 2016), 'p_end1'] = p_exp['p_start1'] + randint(1,3)
p_exp
# Out:
#        id  p_start1  p_end1  p_end2
# 0       1    2015.0  2018.0   -99.0
# 1       2    2012.0  2015.0   -99.0
# 2       3    2008.0  2014.0  2017.0
# 3       4    2015.0  2018.0   -99.0
# 4       5    2015.0  2018.0   -99.0
# 5       6    2010.0  2013.0  2017.0
# 6       7    2015.0  2018.0   -99.0
# 7       8    2013.0  2016.0   -99.0
# 8       9    2012.0  2015.0   -99.0
# 9      10    2009.0  2015.0  2018.0
# 10     11    2010.0  2013.0  2017.0
# 11     12    2008.0  2014.0  2017.0
# 12     13    2016.0  2017.0   -99.0
# 13     14    2009.0  2015.0  2018.0
# 14     15    2017.0  2018.0   -99.0
# 15     16    2009.0  2015.0  2018.0
# 16     17    2008.0  2014.0  2017.0
# 17     18    2015.0  2018.0   -99.0
# 18     19    2015.0  2018.0   -99.0
# 19     20    2014.0  2017.0   -99.0
# 20     21    2014.0  2017.0   -99.0
# 21     22    2006.0  2012.0  2017.0
# 22     23    2011.0  2014.0  2018.0
# 23     24    2013.0  2016.0   -99.0
# 24     25    2013.0  2016.0   -99.0
# ...

# %%
p_exp.to_csv('p_exp.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-308-9e70732b8fdf> in <module>
# ----> 1 p_exp.to_csv('p_exp.csv',index=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
# ...

# %%
p_exp.loc[(p_exp.p_end1 <= 2012), 'p_end2'] = p_exp['p_end1'] + randint(5,6)
p_exp.loc[(p_exp.p_end1 > 2012 )& (p_exp.p_end1 <= 2014), 'p_end2'] =  p_exp['p_end1'] + randint(4,5)
p_exp.loc[(p_exp.p_end1 > 2014 ), 'p_end2'] =-99
p_exp
# Out:
#        id  p_start1  p_end1  p_end2
# 0       1    2015.0  2018.0   -99.0
# 1       2    2012.0  2015.0   -99.0
# 2       3    2008.0  2014.0  2018.0
# 3       4    2015.0  2018.0   -99.0
# 4       5    2015.0  2018.0   -99.0
# 5       6    2010.0  2013.0  2017.0
# 6       7    2015.0  2018.0   -99.0
# 7       8    2013.0  2016.0   -99.0
# 8       9    2012.0  2015.0   -99.0
# 9      10    2009.0  2015.0   -99.0
# 10     11    2010.0  2013.0  2017.0
# 11     12    2008.0  2014.0  2018.0
# 12     13    2016.0  2017.0   -99.0
# 13     14    2009.0  2015.0   -99.0
# 14     15    2017.0  2018.0   -99.0
# 15     16    2009.0  2015.0   -99.0
# 16     17    2008.0  2014.0  2018.0
# 17     18    2015.0  2018.0   -99.0
# 18     19    2015.0  2018.0   -99.0
# 19     20    2014.0  2017.0   -99.0
# 20     21    2014.0  2017.0   -99.0
# 21     22    2006.0  2012.0  2017.0
# 22     23    2011.0  2014.0  2018.0
# 23     24    2013.0  2016.0   -99.0
# 24     25    2013.0  2016.0   -99.0
# ...
